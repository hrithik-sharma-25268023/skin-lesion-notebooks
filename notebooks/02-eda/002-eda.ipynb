# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook contains Exploratory Data Analysis of the Training Images for 2020.

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
from skin_lesion_project.eda import analysis
from skin_lesion_project.utils.eda_utils import LABEL_COLS, CLASS_NAMES

# %%
data_dir = "/mnt/d/skin-lesion-data/2020/ISIC_2020_Training_JPEG/updated_2020_labels.csv"
data = pd.read_csv(data_dir)

# %% [markdown]
# ### Class Distribution Plot

# %%
analysis.plot_class_distribution(data=data)
# Out:
# (diagnosis
#  Melanoma                    584
#  Melanocytic Nevi           5193
#  Basal Cell Carcinoma          0
#  Actinic Keratosis             0
#  Benign Keratosis            223
#  Dermatofibroma                0
#  Vascular Lesion               0
#  Squamous Cell Carcinoma       0
#  Name: count, dtype: int64,
#  diagnosis
#  Melanoma                    9.7
#  Melanocytic Nevi           86.6
#  Basal Cell Carcinoma        0.0
#  Actinic Keratosis           0.0
#  Benign Keratosis            3.7
#  Dermatofibroma              0.0
#  Vascular Lesion             0.0
#  Squamous Cell Carcinoma     0.0
#  Name: count, dtype: float64)

# %% [markdown]
# ## Sample Images Per Class

# %%
analysis.plot_sample_grid(data=data, image_dir="/mnt/d/skin-lesion-data/2020/ISIC_2020_Training_JPEG/train/")
