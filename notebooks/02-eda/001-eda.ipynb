# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook contains Exploratory Data Analysis of the Training Images.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
from skin_lesion_project.eda import analysis
from skin_lesion_project.utils.eda_utils import LABEL_COLS, CLASS_NAMES

# %%
data = pd.read_csv("../../data/2019/ISIC_2019_Training_GroundTruth_2019.csv")

# %%
analysis.plot_class_distribution(data=data)
# Out:
# (Melanocytic Nevi           12875
#  Melanoma                    4522
#  Basal Cell Carcinoma        3323
#  Benign Keratosis            2624
#  Actinic Keratosis            867
#  Squamous Cell Carcinoma      628
#  Vascular Lesion              253
#  Dermatofibroma               239
#  dtype: int64,
#  Melanocytic Nevi           50.8
#  Melanoma                   17.9
#  Basal Cell Carcinoma       13.1
#  Benign Keratosis           10.4
#  Actinic Keratosis           3.4
#  Squamous Cell Carcinoma     2.5
#  Vascular Lesion             1.0
#  Dermatofibroma              0.9
#  dtype: float64)

# %%
analysis.plot_sample_grid(data=data, image_dir="../../data/2019/ISIC_2019_Training_Input/ISIC_2019_Training_Input/")

# %%
analysis.plot_image_sizes(data=data, image_dir="../../data/2019/ISIC_2019_Training_Input/ISIC_2019_Training_Input/")
# Out:
# Width median=1024, min=600, max=1024
# Height median=768, min=450, max=1024

# %%
analysis.plot_pixel_stats(data=data, image_dir="../../data/2019/ISIC_2019_Training_Input/ISIC_2019_Training_Input/", n_samples=1000)
